# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header=None)

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
transactions = []
for i in range (0, 7501):
    transactions.append([str(dataset.values[i, j]) for j in range(0, 20)])

# %% [markdown]
# ## Training Apriori on the dataset

# %%
from apyori import apriori

# %%
rules = apriori(transactions, min_support=0.003, min_confidence=0.2, min_lift=3, min_length=2)

# %% [markdown]
# ## Visualising the results

# %%
results = list(rules)

# %%
for rule in results:
    print(rule[0])
# Out:
# frozenset({'light cream', 'chicken'})
# frozenset({'escalope', 'mushroom cream sauce'})
# frozenset({'escalope', 'pasta'})
# frozenset({'honey', 'fromage blanc'})
# frozenset({'ground beef', 'herb & pepper'})
# frozenset({'ground beef', 'tomato sauce'})
# frozenset({'light cream', 'olive oil'})
# frozenset({'whole wheat pasta', 'olive oil'})
# frozenset({'shrimp', 'pasta'})
# frozenset({'milk', 'avocado', 'spaghetti'})
# frozenset({'milk', 'burgers', 'cake'})
# frozenset({'chocolate', 'burgers', 'turkey'})
# frozenset({'milk', 'burgers', 'turkey'})
# frozenset({'frozen vegetables', 'cake', 'tomatoes'})
# frozenset({'ground beef', 'cereals', 'spaghetti'})
# frozenset({'ground beef', 'chicken', 'milk'})
# frozenset({'light cream', 'chicken', 'nan'})
# frozenset({'milk', 'chicken', 'olive oil'})
# frozenset({'spaghetti', 'chicken', 'olive oil'})
# frozenset({'shrimp', 'chocolate', 'frozen vegetables'})
# frozenset({'ground beef', 'chocolate', 'herb & pepper'})
# frozenset({'milk', 'chocolate', 'soup'})
# frozenset({'ground beef', 'cooking oil', 'spaghetti'})
# frozenset({'ground beef', 'eggs', 'herb & pepper'})
# frozenset({'spaghetti', 'eggs', 'red wine'})
# frozenset({'escalope', 'mushroom cream sauce', 'nan'})
# frozenset({'escalope', 'pasta', 'nan'})
# frozenset({'ground beef', 'herb & pepper', 'french fries'})
# frozenset({'honey', 'nan', 'fromage blanc'})
# frozenset({'frozen vegetables', 'tomatoes', 'green tea'})
# frozenset({'ground beef', 'frozen vegetables', 'spaghetti'})
# frozenset({'milk', 'frozen vegetables', 'olive oil'})
# frozenset({'milk', 'frozen vegetables', 'soup'})
# frozenset({'milk', 'frozen vegetables', 'tomatoes'})
# frozenset({'shrimp', 'frozen vegetables', 'mineral water'})
# frozenset({'spaghetti', 'frozen vegetables', 'olive oil'})
# frozenset({'shrimp', 'frozen vegetables', 'spaghetti'})
# frozenset({'shrimp', 'frozen vegetables', 'tomatoes'})
# frozenset({'spaghetti', 'frozen vegetables', 'tomatoes'})
# frozenset({'ground beef', 'grated cheese', 'spaghetti'})
# frozenset({'ground beef', 'green tea', 'tomatoes'})
# frozenset({'ground beef', 'milk', 'herb & pepper'})
# frozenset({'ground beef', 'mineral water', 'herb & pepper'})
# frozenset({'ground beef', 'nan', 'herb & pepper'})
# frozenset({'ground beef', 'herb & pepper', 'spaghetti'})
# frozenset({'ground beef', 'milk', 'olive oil'})
# frozenset({'ground beef', 'soup', 'milk'})
# frozenset({'ground beef', 'nan', 'tomato sauce'})
# frozenset({'ground beef', 'pepper', 'spaghetti'})
# frozenset({'ground beef', 'shrimp', 'spaghetti'})
# frozenset({'ground beef', 'tomato sauce', 'spaghetti'})
# frozenset({'olive oil', 'light cream', 'nan'})
# frozenset({'milk', 'shrimp', 'olive oil'})
# frozenset({'milk', 'soup', 'olive oil'})
# frozenset({'milk', 'spaghetti', 'olive oil'})
# frozenset({'milk', 'soup', 'tomatoes'})
# frozenset({'milk', 'whole wheat pasta', 'spaghetti'})
# frozenset({'soup', 'mineral water', 'olive oil'})
# frozenset({'whole wheat pasta', 'mineral water', 'olive oil'})
# frozenset({'nan', 'whole wheat pasta', 'olive oil'})
# frozenset({'shrimp', 'pasta', 'nan'})
# frozenset({'spaghetti', 'pancakes', 'olive oil'})
# frozenset({'spaghetti', 'tomatoes', 'olive oil'})
# frozenset({'spaghetti', 'whole wheat rice', 'tomatoes'})
# frozenset({'milk', 'avocado', 'nan', 'spaghetti'})
# frozenset({'milk', 'burgers', 'cake', 'nan'})
# frozenset({'chocolate', 'burgers', 'turkey', 'nan'})
# frozenset({'milk', 'burgers', 'turkey', 'nan'})
# frozenset({'frozen vegetables', 'nan', 'cake', 'tomatoes'})
# frozenset({'ground beef', 'cereals', 'nan', 'spaghetti'})
# frozenset({'ground beef', 'nan', 'chicken', 'milk'})
# frozenset({'milk', 'nan', 'chicken', 'olive oil'})
# frozenset({'spaghetti', 'nan', 'chicken', 'olive oil'})
# frozenset({'ground beef', 'chocolate', 'eggs', 'mineral water'})
# frozenset({'ground beef', 'chocolate', 'frozen vegetables', 'mineral water'})
# frozenset({'ground beef', 'chocolate', 'frozen vegetables', 'spaghetti'})
# frozenset({'milk', 'chocolate', 'frozen vegetables', 'mineral water'})
# frozenset({'milk', 'chocolate', 'frozen vegetables', 'spaghetti'})
# frozenset({'shrimp', 'chocolate', 'frozen vegetables', 'mineral water'})
# frozenset({'shrimp', 'chocolate', 'nan', 'frozen vegetables'})
# frozenset({'ground beef', 'chocolate', 'nan', 'herb & pepper'})
# frozenset({'milk', 'chocolate', 'nan', 'soup'})
# frozenset({'spaghetti', 'chocolate', 'mineral water', 'olive oil'})
# frozenset({'shrimp', 'chocolate', 'mineral water', 'spaghetti'})
# frozenset({'ground beef', 'nan', 'cooking oil', 'spaghetti'})
# frozenset({'milk', 'frozen vegetables', 'eggs', 'mineral water'})
# frozenset({'ground beef', 'nan', 'eggs', 'herb & pepper'})
# frozenset({'spaghetti', 'nan', 'eggs', 'red wine'})
# frozenset({'ground beef', 'nan', 'herb & pepper', 'french fries'})
# frozenset({'milk', 'mineral water', 'spaghetti', 'frozen smoothie'})
# frozenset({'frozen vegetables', 'nan', 'tomatoes', 'green tea'})
# frozenset({'ground beef', 'frozen vegetables', 'milk', 'mineral water'})
# frozenset({'ground beef', 'frozen vegetables', 'milk', 'spaghetti'})
# frozenset({'ground beef', 'frozen vegetables', 'mineral water', 'spaghetti'})
# frozenset({'ground beef', 'frozen vegetables', 'nan', 'spaghetti'})
# frozenset({'milk', 'frozen vegetables', 'mineral water', 'olive oil'})
# frozenset({'milk', 'frozen vegetables', 'soup', 'mineral water'})
# frozenset({'milk', 'frozen vegetables', 'mineral water', 'spaghetti'})
# frozenset({'milk', 'frozen vegetables', 'nan', 'olive oil'})
# frozenset({'milk', 'frozen vegetables', 'nan', 'soup'})
# frozenset({'milk', 'frozen vegetables', 'nan', 'tomatoes'})
# frozenset({'shrimp', 'frozen vegetables', 'nan', 'mineral water'})
# frozenset({'shrimp', 'frozen vegetables', 'mineral water', 'spaghetti'})
# frozenset({'spaghetti', 'frozen vegetables', 'mineral water', 'tomatoes'})
# frozenset({'spaghetti', 'frozen vegetables', 'nan', 'olive oil'})
# frozenset({'shrimp', 'frozen vegetables', 'nan', 'spaghetti'})
# frozenset({'shrimp', 'frozen vegetables', 'nan', 'tomatoes'})
# frozenset({'spaghetti', 'frozen vegetables', 'nan', 'tomatoes'})
# frozenset({'ground beef', 'nan', 'grated cheese', 'spaghetti'})
# frozenset({'ground beef', 'green tea', 'nan', 'tomatoes'})
# frozenset({'ground beef', 'nan', 'milk', 'herb & pepper'})
# frozenset({'ground beef', 'nan', 'mineral water', 'herb & pepper'})
# frozenset({'ground beef', 'nan', 'herb & pepper', 'spaghetti'})
# frozenset({'ground beef', 'nan', 'milk', 'olive oil'})
# frozenset({'ground beef', 'soup', 'nan', 'milk'})
# frozenset({'ground beef', 'mineral water', 'spaghetti', 'olive oil'})
# frozenset({'ground beef', 'mineral water', 'tomatoes', 'spaghetti'})
# frozenset({'ground beef', 'nan', 'pepper', 'spaghetti'})
# frozenset({'ground beef', 'shrimp', 'nan', 'spaghetti'})
# frozenset({'ground beef', 'nan', 'tomato sauce', 'spaghetti'})
# frozenset({'milk', 'mineral water', 'spaghetti', 'olive oil'})
# frozenset({'milk', 'mineral water', 'tomatoes', 'spaghetti'})
# frozenset({'milk', 'shrimp', 'nan', 'olive oil'})
# frozenset({'milk', 'soup', 'nan', 'olive oil'})
# frozenset({'milk', 'nan', 'spaghetti', 'olive oil'})
# frozenset({'milk', 'soup', 'nan', 'tomatoes'})
# frozenset({'milk', 'nan', 'whole wheat pasta', 'spaghetti'})
# frozenset({'soup', 'nan', 'mineral water', 'olive oil'})
# frozenset({'nan', 'whole wheat pasta', 'mineral water', 'olive oil'})
# frozenset({'spaghetti', 'nan', 'pancakes', 'olive oil'})
# frozenset({'spaghetti', 'nan', 'tomatoes', 'olive oil'})
# frozenset({'spaghetti', 'nan', 'whole wheat rice', 'tomatoes'})
# frozenset({'ground beef', 'chocolate', 'nan', 'mineral water', 'eggs'})
# frozenset({'ground beef', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'})
# frozenset({'ground beef', 'chocolate', 'spaghetti', 'nan', 'frozen vegetables'})
# frozenset({'chocolate', 'nan', 'mineral water', 'milk', 'frozen vegetables'})
# frozenset({'chocolate', 'spaghetti', 'nan', 'milk', 'frozen vegetables'})
# frozenset({'shrimp', 'chocolate', 'nan', 'mineral water', 'frozen vegetables'})
# frozenset({'chocolate', 'spaghetti', 'nan', 'mineral water', 'olive oil'})
# frozenset({'shrimp', 'chocolate', 'spaghetti', 'nan', 'mineral water'})
# frozenset({'nan', 'mineral water', 'milk', 'frozen vegetables', 'eggs'})
# frozenset({'frozen smoothie', 'spaghetti', 'nan', 'mineral water', 'milk'})
# frozenset({'ground beef', 'nan', 'mineral water', 'milk', 'frozen vegetables'})
# frozenset({'ground beef', 'spaghetti', 'nan', 'milk', 'frozen vegetables'})
# frozenset({'ground beef', 'spaghetti', 'nan', 'mineral water', 'frozen vegetables'})
# frozenset({'nan', 'mineral water', 'milk', 'frozen vegetables', 'olive oil'})
# frozenset({'soup', 'nan', 'mineral water', 'milk', 'frozen vegetables'})
# frozenset({'spaghetti', 'nan', 'mineral water', 'milk', 'frozen vegetables'})
# frozenset({'shrimp', 'spaghetti', 'nan', 'mineral water', 'frozen vegetables'})
# frozenset({'spaghetti', 'nan', 'mineral water', 'tomatoes', 'frozen vegetables'})
# frozenset({'ground beef', 'spaghetti', 'nan', 'mineral water', 'olive oil'})
# frozenset({'ground beef', 'spaghetti', 'nan', 'mineral water', 'tomatoes'})
# frozenset({'spaghetti', 'nan', 'mineral water', 'milk', 'olive oil'})
# frozenset({'spaghetti', 'nan', 'mineral water', 'tomatoes', 'milk'})
